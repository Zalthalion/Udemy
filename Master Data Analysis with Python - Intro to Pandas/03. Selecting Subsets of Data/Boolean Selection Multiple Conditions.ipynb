# %%
import pandas as pd
movies = pd.read_csv('../data/movie.csv', index_col='title')
movies.head()
# Out:
#                                               year  color content_rating  \
# title
# Avatar                                      2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End    2007.0  Color          PG-13
# Spectre                                     2015.0  Color          PG-13
# The Dark Knight Rises                       2012.0  Color          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
#
#                                             duration      director_name  \
# title
# Avatar                                         178.0      James Cameron
# Pirates of the Caribbean: At World's End       169.0     Gore Verbinski
# Spectre                                        148.0         Sam Mendes
# The Dark Knight Rises                          164.0  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens       NaN        Doug Walker
#
#                                             director_fb           actor1  \
# ...

# %% [markdown]
# ## Exercises
#
# ### Exercise 1
# <span  style="color:green; font-size:16px">Select all movies from the 1970s.</span>

# %%
filter1 = movies['year'] >= 1970
filter2 = movies['year'] < 1980
unioned = filter1 & filter2
seventies = movies[unioned]
seventies.head()
# Out:
#                                  year            color content_rating  \
# title
# All That Jazz                  1979.0            Color              R
# Superman                       1978.0            Color             PG
# Solaris                        1972.0  Black and White             PG
# Mean Streets                   1973.0            Color              R
# Star Trek: The Motion Picture  1979.0            Color             PG
#
#                                duration     director_name  director_fb  \
# title
# All That Jazz                     123.0         Bob Fosse        189.0
# Superman                          188.0    Richard Donner        503.0
# Solaris                           115.0  Andrei Tarkovsky          0.0
# Mean Streets                      112.0   Martin Scorsese      17000.0
# Star Trek: The Motion Picture     143.0       Robert Wise        338.0
#
#                                          actor1  actor1_fb  \
# title
# ...

# %% [markdown]
# ### Exercise 2
# <span  style="color:green; font-size:16px">Select all movies from the 1970s that had IMDB scores greater than 8.</span>

# %%
filter3 = movies['imdb_score'] > 8
unioned  = filter1 & filter2 & filter3
good_seventies = movies[unioned]
good_seventies.head()
# Out:
#                                       year            color content_rating  \
# title
# Solaris                             1972.0  Black and White             PG
# Apocalypse Now                      1979.0            Color              R
# The Deer Hunter                     1978.0            Color              R
# The Godfather: Part II              1974.0            Color              R
# Star Wars: Episode IV - A New Hope  1977.0            Color             PG
#
#                                     duration         director_name  \
# title
# Solaris                                115.0      Andrei Tarkovsky
# Apocalypse Now                         289.0  Francis Ford Coppola
# The Deer Hunter                        183.0        Michael Cimino
# The Godfather: Part II                 220.0  Francis Ford Coppola
# Star Wars: Episode IV - A New Hope     125.0          George Lucas
#
#                                     director_fb            actor1  actor1_fb  \
# title
# ...

# %% [markdown]
# ### Exercise 3
# <span  style="color:green; font-size:16px">Select movies that were rated either R, PG-13, or PG.</span>

# %%
rates = ['R', 'PG-13', 'PG']
filt = movies['content_rating'].isin(rates)
selected_rates = movies[filt]
selected_rates
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
# The Dark Knight Rises                     2012.0  Color          PG-13
# John Carter                               2012.0  Color          PG-13
# ...                                          ...    ...            ...
# Primer                                    2004.0  Color          PG-13
# El Mariachi                               1992.0  Color              R
# The Mongol King                           2005.0  Color          PG-13
# Shanghai Calling                          2012.0  Color          PG-13
# My Date with Drew                         2004.0  Color             PG
#
#                                           duration      director_name  \
# title
# ...

# %% [markdown]
# ### Exercise 4
# <span  style="color:green; font-size:16px">Select movies that are either rated PG-13 or were made after 2010.</span>

# %%
filter_1 = movies['content_rating'] == 'PG-13'
filter_2 = movies['year'] > 2010
filter_combined = filter_1 | filter_2
filtered_movies = movies[filter_combined]
filtered_movies
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
# The Dark Knight Rises                     2012.0  Color          PG-13
# John Carter                               2012.0  Color          PG-13
# ...                                          ...    ...            ...
# The Mongol King                           2005.0  Color          PG-13
# Newlyweds                                 2011.0  Color      Not Rated
# Signed Sealed Delivered                   2013.0  Color            NaN
# A Plague So Pleasant                      2013.0  Color            NaN
# Shanghai Calling                          2012.0  Color          PG-13
#
#                                           duration      director_name  \
# title
# ...

# %% [markdown]
# ### Exercise 5
# <span  style="color:green; font-size:16px">Find all the movies that have at least one of the three actors with more than 10,000 Facebook likes.</span>

# %%
filt0 = movies['actor1_fb'] > 10000
filt2 = movies['actor2_fb'] > 10000
filt3 = movies['actor3_fb'] > 10000
filters_combined = filt0 | filt2 | filt3
popular_actors = movies[filters_combined]
popular_actors
# Out:
#                                             year  color content_rating  \
# title
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
# The Dark Knight Rises                     2012.0  Color          PG-13
# Spider-Man 3                              2007.0  Color          PG-13
# Avengers: Age of Ultron                   2015.0  Color          PG-13
# ...                                          ...    ...            ...
# Like Crazy                                2011.0  Color          PG-13
# Bronson                                   2008.0  Color              R
# A Fistful of Dollars                      1964.0  Color              R
# The Grace Card                            2010.0  Color          PG-13
# Smiling Fish & Goat on Fire               1999.0  Color              R
#
#                                           duration         director_name  \
# title
# ...

# %% [markdown]
# ### Exercise 6
# <span  style="color:green; font-size:16px">Reverse the condition from problem 4. In words, what have you selected?</span>

# %%
# None of the actors have 10k likes
unpopular_actors = movies[~filters_combined]
unpopular_actors
# Out:
#                                               year  color content_rating  \
# title
# Avatar                                      2009.0  Color          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
# John Carter                                 2012.0  Color          PG-13
# Tangled                                     2010.0  Color             PG
# Quantum of Solace                           2008.0  Color          PG-13
# ...                                            ...    ...            ...
# Signed Sealed Delivered                     2013.0  Color            NaN
# The Following                                  NaN  Color          TV-14
# A Plague So Pleasant                        2013.0  Color            NaN
# Shanghai Calling                            2012.0  Color          PG-13
# My Date with Drew                           2004.0  Color             PG
#
#                                             duration     director_name  \
# title
# ...
